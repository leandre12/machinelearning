# %% [markdown]
# # PROJET 4 : Segmentation des clients d'un site e-commerce

# %% [markdown]
# ## SOMMAIRE  <a class="anchor" id="sommaire"></a>
# ## [IMPORT DES LIBRAIRIES](#3)<a class="anchor" id="sommaire"></a>
# ## [CHARGEMENT DES DONNEES](#4)<a class="anchor" id="sommaire"></a>
# ## [MISSION 1: DIFFERENTS TYPES DE SEGMENTATION ](#5)<a class="anchor" id="sommaire"></a>
# ### [M1-1 : RFM](#6)<a class="anchor" id="sommaire"></a>
# #### [M1-1-1 : Préparation des données](#7)<a class="anchor" id="sommaire"></a>
# #### [M1-1-2 : Segmentation RFM](#8)<a class="anchor" id="sommaire"></a>
# ### [M1-2 : K-MEANS](#9)<a class="anchor" id="sommaire"></a>
# #### [M1-2-1 : Segmentation k-means avec les variables RFM](#10)<a class="anchor" id="sommaire"></a>
# #### [M1-2-2 : Segmentation k-means avec plus des variables](#11)<a class="anchor" id="sommaire"></a>
#
# ### [M1-3 : Comparaison des modèles :](#12)<a class="anchor" id="sommaire"></a>

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# ## [IMPORT DES LIBRAIRIES](#sommaire)<a class="anchor" id="3"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from utils.functions import *
import os
from sklearn.cluster import KMeans
from sklearn import preprocessing
import sklearn.manifold as manifold
from sklearn.metrics import silhouette_samples, silhouette_score

# %% [markdown]
# ## [CHARGEMENT DES DONNEES](#sommaire)<a class="anchor" id="4"></a>

# %%
### Lecture du fichier de sauvegarde de DF final
file_df = 'data/final/customers_Final_Behaviour.csv'
file_AllData = 'data/final/AllData.csv'

df = pd.read_csv(file_df, sep='\t', engine='python')
all_Data = pd.read_csv(file_AllData, sep='\t', engine='python')

# %% [markdown]
# ## [MISSION 1: DIFFERENTS TYPES DE SEGMENTATION ](#sommaire)<a class="anchor" id="5"></a>

# %% [markdown]
# ### [M1-1 : RFM ](#sommaire)<a class="anchor" id="6"></a>

# %% [markdown]
# #### [M1-1-1 : Préparation des données](#sommaire)<a class="anchor" id="7"></a>

# %%
df_rfm = df[['customer_id','recency_order','frequency_order','monetary_amount_order']].copy()
df_rfm.fillna(0, inplace = True)

# %%
plt.figure(figsize=(20, 15))
plt.subplot(3, 3, 1)
sns.distplot(df_rfm['recency_order'], kde_kws={'bw': 0.1})
plt.subplot(3, 3, 2)
sns.distplot(df_rfm['frequency_order'], kde_kws={'bw': 0.1})
plt.subplot(3, 3, 3)
sns.distplot(df_rfm['monetary_amount_order'], kde_kws={'bw': 0.1})

# %% [markdown]
# #### Scoring en se basant sur les quartiles :

# %%
# Calcul des score de R
df_rfm['r_percentile'] = df_rfm['recency_order'].rank(method='first')
df_rfm['r_score'] = pd.qcut(df_rfm['r_percentile'], 4,labels=range(4,0,-1))

# Calcul des score de F
df_rfm['f_percentile'] = df_rfm['frequency_order'].rank(method='first')
df_rfm['f_score'] = pd.qcut(df_rfm['f_percentile'], 4, labels=range(4,0,-1))

# Calcul des score de M
df_rfm['m_percentile'] = df_rfm['monetary_amount_order'].rank(method='first')
df_rfm['m_score'] = pd.qcut(df_rfm['m_percentile'], 4, labels=range(4,0,-1))

# Concatenation des scores RFM
df_rfm['rfm_concat_score'] = df_rfm['r_score'].astype(str) + df_rfm['f_score'].astype(str) + df_rfm['m_score'].astype(str)
# Somme des scores R+F+M
df_rfm['rfm_score'] = df_rfm['r_score'].astype(int) + df_rfm['f_score'].astype(int) + df_rfm['m_score'].astype(int)

# %% [markdown]
# #### [M1-1-2 : Segmentation RFM](#sommaire)<a class="anchor" id="8"></a>

# %% [markdown]
# Cette segmentation dependra des besoins clients donc à discuter avec le client mais voici une première repartition :
# -  Best Customers -> =444 (A garder imperativement)
# -  Loyal Customers -> f_score = 4
# -  Big Spenders -> m_score = 4
# -  Almost lost -> r_score <= 2 (A relancer)
# -  Lost Customers (Bon consommateurs mais perdu -> voir ce qu'on peut faire)
# -  Lost Cheap Customers -> 111 (Ne même pas relancer)

# %%
# Créer une nouvelle variable cluster pour determiner les clusters :
df_rfm['rfm_cluster'] = df_rfm.apply(rfm_level_type1, axis=1)

# Faire une transformation inverse de la normalisation faite Log :
df_rfm_inverse = df_rfm.copy()
df_rfm_inverse['frequency_order'] = np.exp(df_rfm['frequency_order']) - 1
df_rfm_inverse['monetary_amount_order'] = np.exp(df_rfm['monetary_amount_order'])-1

# %%
# Calcul des moyennes de chaque rfm_level et la taille de chaque segment 
rfm_level_agg = df_rfm_inverse.groupby('rfm_cluster').agg({
    'recency_order': 'mean',
    'frequency_order': 'mean',
    'monetary_amount_order': ['mean', 'count']
}).round(1)
# Afficher l'agregation
print(rfm_level_agg)
# Out:
#                  recency_order frequency_order monetary_amount_order
#                           mean            mean                  mean  count
# rfm_cluster
# Almost Lost              362.0             1.3                 284.3  27242
# Best Customers            56.8             1.0                  43.4   1619
# Big Spenders             251.6             1.0                  43.6  22097
# Loyal Customers          233.9             1.0                 192.0  17041
# Normal customers         111.5             1.3                 290.2  26863

# %%
# Affichage des repartitions des variables selon les clusters :
cluster_rfm_df = df_rfm_inverse[['recency_order','frequency_order','monetary_amount_order','rfm_cluster']]

radar_plot(cluster_rfm_df, group='rfm_cluster', xsize=0.1, ysize=0.05, figsize=(30, 10))

# %%
# Proportions  selon les cluster 
ax = df_rfm_inverse['rfm_cluster'].value_counts().plot(kind='bar', figsize=(15, 5), fontsize=12)
ax.set_xlabel("Cluster", fontsize=12)
ax.set_ylabel("Proportion des consommateurs ", fontsize=12)
plt.show()

# %% [markdown]
# La frequence n'est pas un très bon parametre car la plupart des consommateurs n'achetent qu'une ou deux fois mais la somme des montants et la recence determinent bien le cluster

# %% [markdown]
# ### [M1-2 : K-Means ](#sommaire)<a class="anchor" id="9"></a>

# %% [markdown]
# #### [M1-2-1 : Segmentation k-means avec les variables RFM](#sommaire)<a class="anchor" id="10"></a>

# %% [markdown]
# #### Préparation des données :

# %%
df_kmeans_rfm = df[['customer_id','recency_order','frequency_order','monetary_amount_order']].copy()

df_kmeans_rfm_in = df_kmeans_rfm.drop(columns=['customer_id'])

# Standardisation des variables d'entrée
X = df_kmeans_rfm_in.values

std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# %% [markdown]
# #### Recherche de nombre de clusters :

# %%
# On caclcule la somme des erreur quadratiques wcss des clusters pour k entre 1 et 20
# choisir la valeur de k ou wcss commence à diminuer (critère du coude)
wcss = []
for k in range(1,21):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    #kmeans.fit(customers_Final_Behaviour_kmeans_in.iloc[:,1:])
    kmeans.fit(X_scaled[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,21),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("nombre des clusters en utilisant les variables RFM")
plt.xticks(np.arange(1,21,1))
plt.ylabel("Somme moyenne des erreurs quadratiques")
plt.title('Clustering avec critère de coude')
plt.show()

# %%
# Selon le "critère du coude" : 
# Décrochement au 5em axe, puis décroissance régulière à partir du 6em axe :
# Donc nos avons ici 6 clusters

# %%
# Clustering pour n_cluster = 5 
kmeansrfm = KMeans(n_clusters=5)
df_kmeans_rfm_in['kmeans_rfm_cluster'] = kmeansrfm.fit_predict(X_scaled[:,1:])

# %% [markdown]
# #### Repartition des variables pour chaque cluster :

# %%
# Affichage des repartitions des variables pour chaque cluster :
radar_plot(df_kmeans_rfm_in, group='kmeans_rfm_cluster', xsize=0.1, ysize=0.05, figsize=(30,10))

# %% [markdown]
# #### Représentation graphique des clusters avec T-SNE :

# %%
kmeansrfm.fit(X_scaled)
kmeansrfm_cluster = kmeansrfm.predict(X_scaled)

np.random.seed(1)
tsne_kmeans_rfm_sample = df_kmeans_rfm_in

# On applique le T-SNE à l'échantillon
tsne = manifold.TSNE(n_components=2, init='pca', perplexity=50, random_state=0)
X_tsne = tsne.fit_transform(tsne_kmeans_rfm_sample)

# %%
# Affichage du graphique
clusters_sample = kmeansrfm_cluster
plt.figure(figsize=(15, 12))
plt.axis([np.min(X_tsne[:, 0] * 1.1), np.max(X_tsne[:, 0] * 1.1),
          np.min(X_tsne[:, 1] * 1.1), np.max(X_tsne[:, 1] * 1.1)])

colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 'goldenrod', 'lightcyan', 'navy','gray','purple']

for i in range(len(np.unique(clusters_sample))):
    idx = clusters_sample == i
    plt.scatter(X_tsne[idx, 0], X_tsne[idx, 1], label=i, s=10, c=colors[i])
    plt.title('T-SNE sur 5 clusters via k-means avec les variables de RFM')

plt.legend(loc='upper left', markerscale=2)
plt.show()

# %%
# Calcul de Silhouette_Score
#
score_kmeansrfm = silhouette_score(X_scaled, kmeansrfm.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouette Score: %.3f' % score_kmeansrfm)
# Out:
# Silhouetter Score: 0.361

# %% [markdown]
# #### [M1-2-1 : Segmentation k-means avec plus des variables : ](#sommaire)<a class="anchor" id="11"></a>

# %%
#### Préparation des données :

# %%
df_kmeans = df.copy()

df_kmeans_in =  df_kmeans.drop(columns=['Unnamed: 0','customer_id', 'customer_unique_id','customer_city','customer_state','order_id'])
df_kmeans_in.fillna(0, inplace = True)

# %%
# Standardisation des variables :
df_kmeans_std = df_kmeans_in.copy()

Xkmeans = df_kmeans_std.values

std_scalekmeans = preprocessing.StandardScaler().fit(Xkmeans)
X_scaledkmeans = std_scale.transform(Xkmeans)

# %% [markdown]
# #### Recherche de nombre de clusters :

# %%
# Determiner les nombres de clusters  avec la methode de Elbow :
# On caclcule la somme des erreur quadratiques wcss des clusters pour k entre 1 et 20
# choisir la valeur de k ou wcss commence à diminuer (critère du coude)
wcss = []
for k in range(1,21):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(X_scaledkmeans[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,21),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("nombre des clusters")
plt.xticks(np.arange(1,21,1))
plt.ylabel("Somme moyenne des erreurs quadratiques")
plt.title('Clustering avec critère de coude')
plt.show()

# %%
# Selon le "critère du coude" : 
# Décrochement au 12em axe, puis décroissance régulière à partir du 13em axe :
# Donc nos avons ici 12 clusters

# %% [markdown]
# #### Générer les clusters :

# %%
# Clustering pour n_cluster = 12 
kmeans = KMeans(n_clusters=12)
df_kmeans_in['kmeans_cluster'] = kmeans.fit_predict(X_scaledkmeans[:,1:])

# Faire une transformation inverse de la normalisation faite Log :
df_kmeans_inverse = df_kmeans_in.copy()

df_kmeans_inverse_copy = df_kmeans_inverse.copy()
listVarDensite = ['frequency_order', 'monetary_amount_order','mean_value_order','nbr_payments_type',
       'amount_sports_leisure', 'amount_health_beauty', 'amount_home',
       'amount_furniture', 'amount_fashion', 'amount_misc',
       'amount_construction', 'amount_electronics', 'amount_supplies',
       'amount_food_drink', 'amount_gifts']
for j,val in enumerate(listVarDensite):
    # transformer les données pour le rendre normales  
    #Les variables qui ont un coeeficient de skewness > 2
    df_kmeans_inverse_copy[val] =  np.exp(df_kmeans_inverse[val])-1  
    jmax = j
    
df_kmeans_inverse_copy.shape
# Out:
# (94862, 20)

# %% [markdown]
# #### Répartition des variables pour chaque cluster :

# %%
# Affichage des repartitions des variables pour chaque cluster :
radar_plot(df_kmeans_inverse_copy, group='kmeans_cluster', xsize=0.25, ysize=0.25, figsize=(25,25))

# %% [markdown]
# #### Représentation graphique des clusters avec T-SNE :

# %%
kmeans.fit(X_scaledkmeans)
kmeans_cluster = kmeans.predict(X_scaledkmeans)

# %% [markdown]
# #### Réduction des dimensions pour afficher les clusters :

# %%
np.random.seed(1)
#tnse_sample = X_scaled
tsne_sample = df_kmeans_in

# On applique le T-SNE à l'échantillon
tsne = manifold.TSNE(n_components=2, init='pca', perplexity=50, random_state=0)
X_tsne = tsne.fit_transform(tsne_sample)

# %%
# Affichage du graphique
clusters_sample = kmeans_cluster
plt.figure(figsize=(15, 12))
plt.axis([np.min(X_tsne[:, 0] * 1.1), np.max(X_tsne[:, 0] * 1.1),
          np.min(X_tsne[:, 1] * 1.1), np.max(X_tsne[:, 1] * 1.1)])

colors = ['royalblue', 'maroon', 'forestgreen', 'mediumorchid', 'tan', 'deeppink', 'olive', 'goldenrod', 'lightcyan', 'navy','gray','purple']

for i in range(len(np.unique(clusters_sample))):
    idx = clusters_sample == i
    plt.scatter(X_tsne[idx, 0], X_tsne[idx, 1], label=i, s=10, c=colors[i])
    plt.title('T-SNE sur 12 clusters via k-means')

plt.legend(loc='upper left', markerscale=2)
plt.show()

# %%
# Calcul de Silhouette_Score
#
score_kmeans = silhouette_score(X_scaledkmeans, kmeans.labels_, metric='euclidean')
#
# Print the score
#
print('Silhouette Score: %.3f' % score_kmeans)
# Out:
# Silhouetter Score: 0.364

# %% [markdown]
# ### [M1-3 : Comparaison des modèles : ](#sommaire)<a class="anchor" id="8"></a>

# %%
On a constaté précedement que le k-means avec plusieres parametres est legerement mieux avec silhouette_score plus elevé.
